# %%
# Import necessary libraries
import geopandas as gpd
import pandas as pd
import requests
from io import BytesIO
from shapely.geometry import MultiLineString, LineString

# %%
# URL of the GeoJSON file
url = 'https://github.com/newzealandpaul/Shipping-Lanes/blob/main/data/Shipping_Lanes_v1.geojson?raw=true'

# Fetch the GeoJSON file
response = requests.get(url)
response.raise_for_status()  # Ensure the request was successful

# Read the GeoJSON data into a GeoDataFrame
geojson_data = BytesIO(response.content)
gdf = gpd.read_file(geojson_data)

# Display the first few rows of the GeoDataFrame
gdf.head()
# Out:
#    FID  OBJECTID    Type                                           geometry
# 0    0         1   Major  MULTILINESTRING ((-34.8576 -8.13738, -34.67437...
# 1    1         2  Middle  MULTILINESTRING ((-52.14663 47.21993, -52.0640...
# 2    2         3   Minor  MULTILINESTRING ((100.43797 13.33198, 100.4257...

# %%
# Explode the MultiLineString geometries into separate LineString geometries
gdf_exploded = gdf.explode(index_parts=False)
# Convert the exploded geometries to LineString
gdf_exploded['geometry'] = gdf_exploded['geometry'].apply(
    lambda geom: LineString(geom) if isinstance(geom, MultiLineString) else geom
)
# Display the first few rows of the exploded GeoDataFrame
gdf_exploded.head()
# Out:
#    FID  OBJECTID   Type                                           geometry
# 0    0         1  Major  LINESTRING (-34.8576 -8.13738, -34.67437 -8.07...
# 0    0         1  Major  LINESTRING (-165.50085 53.93727, -165.06269 53...
# 0    0         1  Major  LINESTRING (-166.54962 54.00381, -166.74346 54...
# 0    0         1  Major  LINESTRING (179.99999 53.13424, 179.9854 53.13...
# 0    0         1  Major  LINESTRING (174.90066 52.38317, 174.57294 52.3...

# %%
# Transform gdf so that there is a single row for each linestring in the coordinates array
# Create a new DataFrame by iterating over the rows and exploding the coordinates
exploded_data = []

for idx, row in gdf.iterrows():
    for line in row['coordinates']:
        exploded_data.append({
            'FID': row['FID'],
            'OBJECTID': row['OBJECTID'],
            'Type': row['Type'],
            'geometry': LineString(line) if isinstance(line, list) else None
        })

# Create a new GeoDataFrame from the exploded data
gdf_exploded = gpd.GeoDataFrame(exploded_data, geometry='geometry', crs=gdf.crs)

# Drop rows where geometry is None
gdf_exploded.dropna(subset=['geometry'], inplace=True)

# Display the first few rows of the exploded GeoDataFrame
gdf_exploded
# Out:
#      FID  OBJECTID   Type                                           geometry
# 0      0         1  Major  LINESTRING (-34.8576 -8.13738, -34.67437 -8.07...
# 1      0         1  Major  LINESTRING (-165.50085 53.93727, -165.06269 53...
# 2      0         1  Major  LINESTRING (-166.54962 54.00381, -166.74346 54...
# 3      0         1  Major  LINESTRING (179.99999 53.13424, 179.9854 53.13...
# 4      0         1  Major  LINESTRING (174.90066 52.38317, 174.57294 52.3...
# ..   ...       ...    ...                                                ...
# 234    2         3  Minor  LINESTRING (-34.40892 -4.66871, -34.75814 -4.2...
# 235    2         3  Minor  LINESTRING (-34.40892 -4.66871, -34.74195 -4.1...
# 236    2         3  Minor  LINESTRING (138.05422 9.42472, 137.99273 9.324...
# 237    2         3  Minor  LINESTRING (-157.88571 21.23252, -157.94719 21...
# 238    2         3  Minor  LINESTRING (180 19.77775, 179.96822 19.77364, ...
#
# [239 rows x 4 columns]

# %%
# Extract the coordinates from the exploded GeoDataFrame
gdf_exploded['coordinates'] = gdf_exploded['geometry'].apply(lambda geom: list(geom.coords))
# Display the first few rows of the updated exploded GeoDataFrame

# Ensure coordinates are shown to the 16th decimal place
gdf_exploded['coordinates'] = gdf_exploded['coordinates'].apply(lambda coords: [[round(coord, 16) for coord in pair] for pair in coords])

gdf_exploded.head()
# Out:
#    FID  OBJECTID   Type                                           geometry  \
# 0    0         1  Major  LINESTRING (-34.8576 -8.13738, -34.67437 -8.07...
# 0    0         1  Major  LINESTRING (-165.50085 53.93727, -165.06269 53...
# 0    0         1  Major  LINESTRING (-166.54962 54.00381, -166.74346 54...
# 0    0         1  Major  LINESTRING (179.99999 53.13424, 179.9854 53.13...
# 0    0         1  Major  LINESTRING (174.90066 52.38317, 174.57294 52.3...
#
#                                          coordinates
# 0  [[-34.85759679699993, -8.13737959499997], [-34...
# 0  [[-165.50085262999997, 53.93727424300005], [-1...
# 0  [[-166.54962390799997, 54.003807401000074], [-...
# 0  [[179.99998854000012, 53.134237075000044], [17...
# 0  [[174.90065502200002, 52.38316970000005], [174...

# %%
from math import radians, cos, sin, asin, sqrt, atan2, degrees
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees), returns kilometers.
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371  # Radius of earth in kilometers. Use 3956 for miles.
    return c * r


def process_coordinates(row, row_index):
    """Process coordinates to create a dictionary with FID, OBJECTID, Type, and coordinates."""
    df = pd.DataFrame(columns=['source', 'target', 'weight', 'lane-type', 'lane-idx'])

    for i, coord in enumerate(row['coordinates'][:-1]):
        # Print the current coordinate
        print(f"Processing coordinate {i}: {coord}")

        # Compare with the next coordinate if not the last one
        if i < len(row['coordinates']) - 1:
            next_coord = row['coordinates'][i + 1]
            print(f"\tComparing with next coordinate: {next_coord}")
    
        # Calculate the distance bewteen coord and next_coord using the haversine formula
        dist = haversine(coord[0], coord[1], next_coord[0], next_coord[1]) if i < len(row['coordinates']) - 1 else None
        print(f"\tDistance to next coordinate: {dist} km")


        # Append a new row to the DataFrame
        df = pd.concat([
            df,
            pd.DataFrame({
                'source': [coord],
                'target': [next_coord],
                'weight': [dist],
                'lane-type': [row['Type']],
                'lane-idx': int(row_index),
            })
        ], ignore_index=True)

    return df

# Apply this function to all rows
processed_rows = []
for index, row in gdf_exploded.iterrows():
    processed_row = process_coordinates(row, index)
    processed_rows.append(processed_row)
# Concatenate all processed rows into a single DataFrame
final_df = pd.concat(processed_rows, ignore_index=True)

# Display the first few rows of the final DataFrame
final_df.head()
# Save the final DataFrame to a CSV file
final_df.to_csv('shipping_lanes.csv', index=False)
# Out:
# Processing coordinate 0: [-34.85759679699993, -8.13737959499997]
# 	Comparing with next coordinate: [-34.67436962399995, -8.070254808999948]
# 	Distance to next coordinate: 21.507177441064414 km
# Processing coordinate 1: [-34.67436962399995, -8.070254808999948]
# 	Comparing with next coordinate: [-34.674368303999984, -8.070249185999955]
# 	Distance to next coordinate: 0.0006419154028373217 km
# Processing coordinate 2: [-34.674368303999984, -8.070249185999955]
# 	Comparing with next coordinate: [-25.630149081999946, 16.957174956000074]
# 	Distance to next coordinate: 2955.2686346210367 km
# Processing coordinate 3: [-25.630149081999946, 16.957174956000074]
# 	Comparing with next coordinate: [-25.483361960999957, 17.286788839000053]
# 	Distance to next coordinate: 39.832647359458875 km
# Processing coordinate 4: [-25.483361960999957, 17.286788839000053]
# 	Comparing with next coordinate: [-25.337770409999962, 17.616515286000038]
# 	Distance to next coordinate: 39.78384456392597 km
# Processing coordinate 5: [-25.337770409999962, 17.616515286000038]
# 	Comparing with next coordinate: [-25.190650972999947, 17.94635471500004]
# 	Distance to next coordinate: 39.847451059891974 km
# Processing coordinate 6: [-25.190650972999947, 17.94635471500004]
# 	Comparing with next coordinate: [-24.99966827399993, 18.37701545400006]
# 	Distance to next coordinate: 51.96493892057804 km
# Processing coordinate 7: [-24.99966827399993, 18.37701545400006]
# 	Comparing with next coordinate: [-24.806104355999935, 18.807669188000034]
# 	Distance to next coordinate: 52.05071628570021 km
# Processing coordinate 8: [-24.806104355999935, 18.807669188000034]
# 	Comparing with next coordinate: [-24.411254697999937, 19.66897126500004]
# 	Distance to next coordinate: 104.35851459193803 km
# Processing coordinate 9: [-24.411254697999937, 19.66897126500004]
# 	Comparing with next coordinate: [-24.211280570999975, 20.099627421000037]
# 	Distance to next coordinate: 52.25310035238967 km
# Processing coordinate 10: [-24.211280570999975, 20.099627421000037]
# 	Comparing with next coordinate: [-24.013673022999967, 20.53029219600006]
# 	Distance to next coordinate: 52.132985177947596 km
# Processing coordinate 11: [-24.013673022999967, 20.53029219600006]
# 	Comparing with next coordinate: [-23.81449352599998, 20.960969498000054]
# 	Distance to next coordinate: 52.176067751981314 km
# Processing coordinate 12: [-23.81449352599998, 20.960969498000054]
# 	Comparing with next coordinate: [-23.714317912999945, 21.17631406600003]
# 	Distance to next coordinate: 26.10395943430598 km
# Processing coordinate 13: [-23.714317912999945, 21.17631406600003]
# 	Comparing with next coordinate: [-23.61375363899998, 21.39166323200004]
# 	Distance to next coordinate: 26.114451212896032 km
# Processing coordinate 14: [-23.61375363899998, 21.39166323200004]
# 	Comparing with next coordinate: [-23.512802129999955, 21.60701748100007]
# 	Distance to next coordinate: 26.124847313180776 km
# Processing coordinate 15: [-23.512802129999955, 21.60701748100007]
# 	Comparing with next coordinate: [-23.41146480499998, 21.822377304000042]
# 	Distance to next coordinate: 26.135147229016066 km
# Processing coordinate 16: [-23.41146480499998, 21.822377304000042]
# 	Comparing with next coordinate: [-23.30974307599996, 22.037743189000025]
# 	Distance to next coordinate: 26.145349561420534 km
# Processing coordinate 17: [-23.30974307599996, 22.037743189000025]
# 	Comparing with next coordinate: [-23.207638347999932, 22.253115622000053]
# 	Distance to next coordinate: 26.155453038350686 km
# Processing coordinate 18: [-23.207638347999932, 22.253115622000053]
# 	Comparing with next coordinate: [-23.10515201499993, 22.468495094000048]
# 	Distance to next coordinate: 26.16545729069638 km
# Processing coordinate 19: [-23.10515201499993, 22.468495094000048]
# 	Comparing with next coordinate: [-23.002285469999947, 22.683882092000033]
# 	Distance to next coordinate: 26.175360643353415 km
# Processing coordinate 20: [-23.002285469999947, 22.683882092000033]
# 	Comparing with next coordinate: [-22.89904009299994, 22.899277104000078]
# 	Distance to next coordinate: 26.18516245181985 km
# Processing coordinate 21: [-22.89904009299994, 22.899277104000078]
# 	Comparing with next coordinate: [-22.795417260999955, 23.11468061900007]
# 	Distance to next coordinate: 26.194861681523733 km
# Processing coordinate 22: [-22.795417260999955, 23.11468061900007]
# 	Comparing with next coordinate: [-22.69141833699996, 23.330093126000065]
# 	Distance to next coordinate: 26.20445767624552 km
# Processing coordinate 23: [-22.69141833699996, 23.330093126000065]
# 	Comparing with next coordinate: [-22.587044684999967, 23.545515112000032]
# 	Distance to next coordinate: 26.213948979181524 km
# Processing coordinate 24: [-22.587044684999967, 23.545515112000032]
# 	Comparing with next coordinate: [-22.482297655999957, 23.76094706500004]
# 	Distance to next coordinate: 26.223335042873718 km
# Processing coordinate 25: [-22.482297655999957, 23.76094706500004]
# 	Comparing with next coordinate: [-22.377178595999965, 23.97638947400003]
# 	Distance to next coordinate: 26.232615012217092 km
# Processing coordinate 26: [-22.377178595999965, 23.97638947400003]
# 	Comparing with next coordinate: [-22.271688839999968, 24.191842828000063]
# 	Distance to next coordinate: 26.241788203075156 km
# Processing coordinate 27: [-22.271688839999968, 24.191842828000063]
# 	Comparing with next coordinate: [-22.165829720999966, 24.407307615000036]
# 	Distance to next coordinate: 26.25085348083665 km
# Processing coordinate 28: [-22.165829720999966, 24.407307615000036]
# 	Comparing with next coordinate: [-22.059602561999952, 24.62278432100004]
# 	Distance to next coordinate: 26.259809964917604 km
# Processing coordinate 29: [-22.059602561999952, 24.62278432100004]
# 	Comparing with next coordinate: [-21.953008676999957, 24.838273438000044]
# 	Distance to next coordinate: 26.26865756850874 km
# Processing coordinate 30: [-21.953008676999957, 24.838273438000044]
# 	Comparing with next coordinate: [-21.79133603799994, 25.164524149000044]
# 	Distance to next coordinate: 39.768094872209254 km
# Processing coordinate 31: [-21.79133603799994, 25.164524149000044]
# 	Comparing with next coordinate: [-21.62771737299994, 25.490788158000043]
# 	Distance to next coordinate: 39.83198041126896 km
# Processing coordinate 32: [-21.62771737299994, 25.490788158000043]
# 	Comparing with next coordinate: [-21.521665320999944, 25.702258882000024]
# 	Distance to next coordinate: 25.807673696736494 km
# Processing coordinate 33: [-21.521665320999944, 25.702258882000024]
# 	Comparing with next coordinate: [-21.415052825999965, 25.91379898100007]
# 	Distance to next coordinate: 25.830060009703896 km
# Processing coordinate 34: [-21.415052825999965, 25.91379898100007]
# 	Comparing with next coordinate: [-21.307886192999945, 26.125408640000046]
# 	Distance to next coordinate: 25.852094732215843 km
# Processing coordinate 35: [-21.307886192999945, 26.125408640000046]
# 	Comparing with next coordinate: [-21.20017170999995, 26.33708804300005]
# 	Distance to next coordinate: 25.873775726308935 km
# Processing coordinate 36: [-21.20017170999995, 26.33708804300005]
# 	Comparing with next coordinate: [-21.09191564799994, 26.548837373000026]
# 	Distance to next coordinate: 25.895100992296406 km
# Processing coordinate 37: [-21.09191564799994, 26.548837373000026]
# 	Comparing with next coordinate: [-20.983124261999933, 26.76065681700004]
# 	Distance to next coordinate: 25.9160691308217 km
# Processing coordinate 38: [-20.983124261999933, 26.76065681700004]
# 	Comparing with next coordinate: [-20.873803788999965, 26.972546558000033]
# 	Distance to next coordinate: 25.93667815119148 km
# Processing coordinate 39: [-20.873803788999965, 26.972546558000033]
# 	Comparing with next coordinate: [-20.763960450999946, 27.18450678100004]
# 	Distance to next coordinate: 25.956926677891254 km
# Processing coordinate 40: [-20.763960450999946, 27.18450678100004]
# 	Comparing with next coordinate: [-20.653600452999967, 27.396537671000033]
# 	Distance to next coordinate: 25.976813347330754 km
# Processing coordinate 41: [-20.653600452999967, 27.396537671000033]
# 	Comparing with next coordinate: [-20.542729986999973, 27.60863941200006]
# 	Distance to next coordinate: 25.996336658791456 km
# Processing coordinate 42: [-20.542729986999973, 27.60863941200006]
# 	Comparing with next coordinate: [-20.431355225999937, 27.820812189000037]
# 	Distance to next coordinate: 26.015495690309304 km
# Processing coordinate 43: [-20.431355225999937, 27.820812189000037]
# 	Comparing with next coordinate: [-20.31948233199995, 28.033056187000057]
# 	Distance to next coordinate: 26.034289213523465 km
# Processing coordinate 44: [-20.31948233199995, 28.033056187000057]
# 	Comparing with next coordinate: [-20.20711745099993, 28.245371590000047]
# 	Distance to next coordinate: 26.052716231653395 km
# Processing coordinate 45: [-20.20711745099993, 28.245371590000047]
# 	Comparing with next coordinate: [-20.094266716999982, 28.457758582000054]
# 	Distance to next coordinate: 26.07077580633658 km
# Processing coordinate 46: [-20.094266716999982, 28.457758582000054]
# 	Comparing with next coordinate: [-19.980936245999942, 28.67021734900004]
# 	Distance to next coordinate: 26.088467571175737 km
# Processing coordinate 47: [-19.980936245999942, 28.67021734900004]
# 	Comparing with next coordinate: [-19.86713214399998, 28.882748075000052]
# 	Distance to next coordinate: 26.10579054565654 km
# Processing coordinate 48: [-19.86713214399998, 28.882748075000052]
# 	Comparing with next coordinate: [-19.752860505999934, 29.095350944000074]
# 	Distance to next coordinate: 26.122744111510503 km
# Processing coordinate 49: [-19.752860505999934, 29.095350944000074]
# 	Comparing with next coordinate: [-19.638127407999946, 29.308026141000028]
# 	Distance to next coordinate: 26.139328199671688 km
# Processing coordinate 50: [-19.638127407999946, 29.308026141000028]
# 	Comparing with next coordinate: [-19.522938919999945, 29.52077385000007]
# 	Distance to next coordinate: 26.155542118120053 km
# Processing coordinate 51: [-19.522938919999945, 29.52077385000007]
# 	Comparing with next coordinate: [-19.40730109699996, 29.73359425700005]
# 	Distance to next coordinate: 26.17138596372269 km
# Processing coordinate 52: [-19.40730109699996, 29.73359425700005]
# 	Comparing with next coordinate: [-19.291219981999973, 29.94648754600007]
# 	Distance to next coordinate: 26.186859420471528 km
# Processing coordinate 53: [-19.291219981999973, 29.94648754600007]
# 	Comparing with next coordinate: [-19.17357990499994, 30.159453901000063]
# 	Distance to next coordinate: 26.248350402999865 km
# Processing coordinate 54: [-19.17357990499994, 30.159453901000063]
# 	Comparing with next coordinate: [-19.05501912999995, 30.37249350700006]
# 	Distance to next coordinate: 26.283357298947617 km
# Processing coordinate 55: [-19.05501912999995, 30.37249350700006]
# 	Comparing with next coordinate: [-18.935903224999947, 30.585606548000044]
# 	Distance to next coordinate: 26.303033124240404 km
# Processing coordinate 56: [-18.935903224999947, 30.585606548000044]
# 	Comparing with next coordinate: [-18.816237394999973, 30.79879321100003]
# 	Distance to next coordinate: 26.322356155137726 km
# Processing coordinate 57: [-18.816237394999973, 30.79879321100003]
# 	Comparing with next coordinate: [-18.696026823999944, 31.01205367700004]
# 	Distance to next coordinate: 26.341325145947643 km
# Processing coordinate 58: [-18.696026823999944, 31.01205367700004]
# 	Comparing with next coordinate: [-18.57527667499994, 31.225388133000024]
# 	Distance to next coordinate: 26.359940157729547 km
# Processing coordinate 59: [-18.57527667499994, 31.225388133000024]
# 	Comparing with next coordinate: [-18.45399208699996, 31.438796763000028]
# 	Distance to next coordinate: 26.378200578372535 km
# Processing coordinate 60: [-18.45399208699996, 31.438796763000028]
# 	Comparing with next coordinate: [-18.33217818199995, 31.652279752000027]
# 	Distance to next coordinate: 26.396106007793836 km
# Processing coordinate 61: [-18.33217818199995, 31.652279752000027]
# 	Comparing with next coordinate: [-18.209840059999976, 31.865837283000076]
# 	Distance to next coordinate: 26.413656054119368 km
# Processing coordinate 62: [-18.209840059999976, 31.865837283000076]
# 	Comparing with next coordinate: [-18.086982800999976, 32.07946954200003]
# 	Distance to next coordinate: 26.430850841658494 km
# Processing coordinate 63: [-18.086982800999976, 32.07946954200003]
# 	Comparing with next coordinate: [-17.96361146299995, 32.293176714000026]
# 	Distance to next coordinate: 26.447690275243126 km
# Processing coordinate 64: [-17.96361146299995, 32.293176714000026]
# 	Comparing with next coordinate: [-17.77531367299997, 32.614450601000044]
# 	Distance to next coordinate: 39.854171087994736 km
# Processing coordinate 65: [-17.77531367299997, 32.614450601000044]
# 	Comparing with next coordinate: [-17.58702861599994, 32.93537101700008]
# 	Distance to next coordinate: 39.79039600485853 km
# Processing coordinate 66: [-17.58702861599994, 32.93537101700008]
# 	Comparing with next coordinate: [-17.395991034999952, 33.255952498000056]
# 	Distance to next coordinate: 39.842291809588936 km
# Processing coordinate 67: [-17.395991034999952, 33.255952498000056]
# 	Comparing with next coordinate: [-17.204891651999958, 33.576307608000036]
# 	Distance to next coordinate: 39.79325277306881 km
# Processing coordinate 68: [-17.204891651999958, 33.576307608000036]
# 	Comparing with next coordinate: [-17.080571546999977, 33.783254930000055]
# 	Distance to next coordinate: 25.726594279652737 km
# Processing coordinate 69: [-17.080571546999977, 33.783254930000055]
# 	Comparing with next coordinate: [-16.95532424499993, 33.99021141600008]
# 	Distance to next coordinate: 25.75341163057182 km
# Processing coordinate 70: [-16.95532424499993, 33.99021141600008]
# 	Comparing with next coordinate: [-16.829143814999952, 34.19717743100006]
# 	Distance to next coordinate: 25.780357475686582 km
# Processing coordinate 71: [-16.829143814999952, 34.19717743100006]
# 	Comparing with next coordinate: [-16.70202425499997, 34.40415333100003]
# 	Distance to next coordinate: 25.807430123739852 km
# Processing coordinate 72: [-16.70202425499997, 34.40415333100003]
# 	Comparing with next coordinate: [-16.573959487999957, 34.61113947500007]
# 	Distance to next coordinate: 25.83462919466854 km
# Processing coordinate 73: [-16.573959487999957, 34.61113947500007]
# 	Comparing with next coordinate: [-16.44494336599996, 34.818136225000046]
# 	Distance to next coordinate: 25.861954092330905 km
# Processing coordinate 74: [-16.44494336599996, 34.818136225000046]
# 	Comparing with next coordinate: [-16.315126608999947, 35.02518476400007]
# 	Distance to next coordinate: 25.886893181652088 km
# Processing coordinate 75: [-16.315126608999947, 35.02518476400007]
# 	Comparing with next coordinate: [-16.185541875999945, 35.23255551300008]
# 	Distance to next coordinate: 25.89548469194664 km
# Processing coordinate 76: [-16.185541875999945, 35.23255551300008]
# 	Comparing with next coordinate: [-16.077770907999934, 35.404042762000074]
# 	Distance to next coordinate: 21.42937396635949 km
# Processing coordinate 77: [-16.077770907999934, 35.404042762000074]
# 	Comparing with next coordinate: [-16.055095367999968, 35.43996576400008]
# 	Distance to next coordinate: 4.491936395174482 km
# Processing coordinate 78: [-16.055095367999968, 35.43996576400008]
# 	Comparing with next coordinate: [-15.923780922999981, 35.647415892000026]
# 	Distance to next coordinate: 25.947233739781414 km
# Processing coordinate 79: [-15.923780922999981, 35.647415892000026]
# 	Comparing with next coordinate: [-15.791592309999942, 35.854906275000076]
# 	Distance to next coordinate: 25.973256424446788 km
# Processing coordinate 80: [-15.791592309999942, 35.854906275000076]
# 	Comparing with next coordinate: [-15.658523226999932, 36.06243728900006]
# 	Distance to next coordinate: 25.999376774476225 km
# Processing coordinate 81: [-15.658523226999932, 36.06243728900006]
# 	Comparing with next coordinate: [-15.524567304999948, 36.270009310000034]
# 	Distance to next coordinate: 26.025593820997756 km
# Processing coordinate 82: [-15.524567304999948, 36.270009310000034]
# 	Comparing with next coordinate: [-15.389718100999971, 36.47762271600004]
# 	Distance to next coordinate: 26.051907027801178 km
# Processing coordinate 83: [-15.389718100999971, 36.47762271600004]
# 	Comparing with next coordinate: [-15.253969103999964, 36.685277883000026]
# 	Distance to next coordinate: 26.07831515986261 km
# Processing coordinate 84: [-15.253969103999964, 36.685277883000026]
# 	Comparing with next coordinate: [-15.117313726999953, 36.89297519100006]
# 	Distance to next coordinate: 26.104817848472255 km
# Processing coordinate 85: [-15.117313726999953, 36.89297519100006]
# 	Comparing with next coordinate: [-14.979745310999931, 37.10071501300007]
# 	Distance to next coordinate: 26.1314134191422 km
# Processing coordinate 86: [-14.979745310999931, 37.10071501300007]
# 	Comparing with next coordinate: [-14.84125712399998, 37.308497732000035]
# 	Distance to next coordinate: 26.15810185225505 km
# Processing coordinate 87: [-14.84125712399998, 37.308497732000035]
# 	Comparing with next coordinate: [-14.70184235499994, 37.51632372200004]
# 	Distance to next coordinate: 26.184881450215563 km
# Processing coordinate 88: [-14.70184235499994, 37.51632372200004]
# 	Comparing with next coordinate: [-14.561494120999953, 37.72419336200005]
# 	Distance to next coordinate: 26.211751540108313 km
# Processing coordinate 89: [-14.561494120999953, 37.72419336200005]
# 	Comparing with next coordinate: [-14.420205456999952, 37.93210703300008]
# 	Distance to next coordinate: 26.23871150716403 km
# Processing coordinate 90: [-14.420205456999952, 37.93210703300008]
# 	Comparing with next coordinate: [-14.277969325999948, 38.14006511000008]
# 	Distance to next coordinate: 26.26575947516093 km
# Processing coordinate 91: [-14.277969325999948, 38.14006511000008]
# 	Comparing with next coordinate: [-14.134778604999951, 38.34806797300007]
# 	Distance to next coordinate: 26.2928951637915 km
# Processing coordinate 92: [-14.134778604999951, 38.34806797300007]
# 	Comparing with next coordinate: [-13.990626095999971, 38.55611600200007]
# 	Distance to next coordinate: 26.3201172807824 km
# Processing coordinate 93: [-13.990626095999971, 38.55611600200007]
# 	Comparing with next coordinate: [-13.871903832999976, 38.72648803800007]
# 	Distance to next coordinate: 21.568820635830214 km
# Processing coordinate 94: [-13.871903832999976, 38.72648803800007]
# 	Comparing with next coordinate: [-13.845504515999949, 38.76420957500005]
# 	Distance to next coordinate: 4.778604375207505 km
# Processing coordinate 95: [-13.845504515999949, 38.76420957500005]
# 	Comparing with next coordinate: [-13.699406503999967, 38.97234907300003]
# 	Distance to next coordinate: 26.374816379354687 km
# Processing coordinate 96: [-13.699406503999967, 38.97234907300003]
# 	Comparing with next coordinate: [-13.55232461099996, 39.180534874000045]
# 	Distance to next coordinate: 26.402291108499686 km
# Processing coordinate 97: [-13.55232461099996, 39.180534874000045]
# 	Comparing with next coordinate: [-13.404251306999981, 39.38876735800005]
# 	Distance to next coordinate: 26.42984775848415 km
# Processing coordinate 98: [-13.404251306999981, 39.38876735800005]
# 	Comparing with next coordinate: [-13.255178974999978, 39.59704690700005]
# 	Distance to next coordinate: 26.45748539010085 km
# Processing coordinate 99: [-13.255178974999978, 39.59704690700005]
# 	Comparing with next coordinate: [-13.105099910999968, 39.805373899000074]
# 	Distance to next coordinate: 26.485202408537283 km
# Processing coordinate 100: [-13.105099910999968, 39.805373899000074]
# 	Comparing with next coordinate: [-12.953880564999963, 40.013782314000025]
# 	Distance to next coordinate: 26.52147611937767 km
# Processing coordinate 101: [-12.953880564999963, 40.013782314000025]
# 	Comparing with next coordinate: [-12.799765897999976, 40.22273744100005]
# 	Distance to next coordinate: 26.675602735399508 km
# Processing coordinate 102: [-12.799765897999976, 40.22273744100005]
# 	Comparing with next coordinate: [-12.570053500999961, 40.534783951000065]
# 	Distance to next coordinate: 39.781413738775974 km
# Processing coordinate 103: [-12.570053500999961, 40.534783951000065]
# 	Comparing with next coordinate: [-12.337440575999949, 40.84639057700008]
# 	Distance to next coordinate: 39.814490100578176 km
# Processing coordinate 104: [-12.337440575999949, 40.84639057700008]
# 	Comparing with next coordinate: [-12.179372369999953, 41.05521586000003]
# 	Distance to next coordinate: 26.74708928820255 km
# Processing coordinate 105: [-12.179372369999953, 41.05521586000003]
# 	Comparing with next coordinate: [-12.020434226999953, 41.26403617100004]
# 	Distance to next coordinate: 26.761886584053638 km
# Processing coordinate 106: [-12.020434226999953, 41.26403617100004]
# 	Comparing with next coordinate: [-11.86055919499995, 41.47285632100005]
# 	Distance to next coordinate: 26.77963901708144 km
# Processing coordinate 107: [-11.86055919499995, 41.47285632100005]
# 	Comparing with next coordinate: [-11.699679853999953, 41.68168112500007]
# 	Distance to next coordinate: 26.800351733934107 km
# Processing coordinate 108: [-11.699679853999953, 41.68168112500007]
# 	Comparing with next coordinate: [-11.537728300999959, 41.890515407000066]
# 	Distance to next coordinate: 26.82403214595259 km
# Processing coordinate 109: [-11.537728300999959, 41.890515407000066]
# 	Comparing with next coordinate: [-11.374636149999958, 42.09936399700007]
# 	Distance to next coordinate: 26.850688475899798 km
# Processing coordinate 110: [-11.374636149999958, 42.09936399700007]
# 	Comparing with next coordinate: [-11.210334510999928, 42.308231731000035]
# 	Distance to next coordinate: 26.88033085753525 km
# Processing coordinate 111: [-11.210334510999928, 42.308231731000035]
# 	Comparing with next coordinate: [-11.044753991999926, 42.51712345200008]
# 	Distance to next coordinate: 26.91297041242812 km
# Processing coordinate 112: [-11.044753991999926, 42.51712345200008]
# 	Comparing with next coordinate: [-10.877824678999957, 42.72604401000007]
# 	Distance to next coordinate: 26.948619998446123 km
# Processing coordinate 113: [-10.877824678999957, 42.72604401000007]
# 	Comparing with next coordinate: [-10.709476132999953, 42.93499826000004]
# 	Distance to next coordinate: 26.987293243053106 km
# Processing coordinate 114: [-10.709476132999953, 42.93499826000004]
# 	Comparing with next coordinate: [-10.539637372999948, 43.14399106600007]
# 	Distance to next coordinate: 27.029005625712234 km
# Processing coordinate 115: [-10.539637372999948, 43.14399106600007]
# 	Comparing with next coordinate: [-10.368236871999954, 43.35302729700004]
# 	Distance to next coordinate: 27.07377309691805 km
# Processing coordinate 116: [-10.368236871999954, 43.35302729700004]
# 	Comparing with next coordinate: [-10.195202543999926, 43.56211182800007]
# 	Distance to next coordinate: 27.12161285314923 km
# Processing coordinate 117: [-10.195202543999926, 43.56211182800007]
# 	Comparing with next coordinate: [-10.02046172799993, 43.771249545000046]
# 	Distance to next coordinate: 27.172543761482068 km
# Processing coordinate 118: [-10.02046172799993, 43.771249545000046]
# 	Comparing with next coordinate: [-9.84394118399996, 43.98044533400008]
# 	Distance to next coordinate: 27.226584255194762 km
# Processing coordinate 119: [-9.84394118399996, 43.98044533400008]
# 	Comparing with next coordinate: [-9.665567075999945, 44.189704092000056]
# 	Distance to next coordinate: 27.28375488539979 km
# Processing coordinate 120: [-9.665567075999945, 44.189704092000056]
# 	Comparing with next coordinate: [-9.485264966999978, 44.39903072300007]
# 	Distance to next coordinate: 27.34407630598278 km
# Processing coordinate 121: [-9.485264966999978, 44.39903072300007]
# 	Comparing with next coordinate: [-9.302959795999925, 44.60843013600004]
# 	Distance to next coordinate: 27.407570129578662 km
# Processing coordinate 122: [-9.302959795999925, 44.60843013600004]
# 	Comparing with next coordinate: [-9.118575876999955, 44.81790724700005]
# 	Distance to next coordinate: 27.47425829930467 km
# Processing coordinate 123: [-9.118575876999955, 44.81790724700005]
# 	Comparing with next coordinate: [-8.932588045999978, 45.027535009000076]
# 	Distance to next coordinate: 27.527450376147286 km
# Processing coordinate 124: [-8.932588045999978, 45.027535009000076]
# 	Comparing with next coordinate: [-8.748232560999952, 45.23772636800004]
# 	Distance to next coordinate: 27.484525315790677 km
# Processing coordinate 125: [-8.748232560999952, 45.23772636800004]
# 	Comparing with next coordinate: [-8.561940366999977, 45.44805443800004]
# 	Distance to next coordinate: 27.54909312868409 km
# Processing coordinate 126: [-8.561940366999977, 45.44805443800004]
# 	Comparing with next coordinate: [-8.373636320999935, 45.658524311000065]
# 	Distance to next coordinate: 27.616731380810776 km
# Processing coordinate 127: [-8.373636320999935, 45.658524311000065]
# 	Comparing with next coordinate: [-8.183244698999943, 45.86914108700006]
# 	Distance to next coordinate: 27.687453682249764 km
# Processing coordinate 128: [-8.183244698999943, 45.86914108700006]
# 	Comparing with next coordinate: [-7.990689174999943, 46.07990988100005]
# 	Distance to next coordinate: 27.76127505979028 km
# Processing coordinate 129: [-7.990689174999943, 46.07990988100005]
# 	Comparing with next coordinate: [-7.79589281799997, 46.29083581700007]
# 	Distance to next coordinate: 27.838209897363782 km
# Processing coordinate 130: [-7.79589281799997, 46.29083581700007]
# 	Comparing with next coordinate: [-7.598778079999931, 46.501924030000055]
# 	Distance to next coordinate: 27.918272969957652 km
# Processing coordinate 131: [-7.598778079999931, 46.501924030000055]
# 	Comparing with next coordinate: [-7.3992667759999335, 46.713179670000045]
# 	Distance to next coordinate: 28.001479868264195 km
# Processing coordinate 132: [-7.3992667759999335, 46.713179670000045]
# 	Comparing with next coordinate: [-7.197280083999942, 46.92460789800003]
# 	Distance to next coordinate: 28.087845326810573 km
# Processing coordinate 133: [-7.197280083999942, 46.92460789800003]
# 	Comparing with next coordinate: [-6.9927385259999255, 47.13621388200005]
# 	Distance to next coordinate: 28.1773839244316 km
# Processing coordinate 134: [-6.9927385259999255, 47.13621388200005]
# 	Comparing with next coordinate: [-6.78556195699997, 47.34800280800005]
# 	Distance to next coordinate: 28.27011105244302 km
# Processing coordinate 135: [-6.78556195699997, 47.34800280800005]
# 	Comparing with next coordinate: [-6.57566955599998, 47.559979869000074]
# 	Distance to next coordinate: 28.366040692250518 km
# Processing coordinate 136: [-6.57566955599998, 47.559979869000074]
# 	Comparing with next coordinate: [-6.280572369999959, 47.85761400100006]
# 	Distance to next coordinate: 39.78477652631727 km
# Processing coordinate 137: [-6.280572369999959, 47.85761400100006]
# 	Comparing with next coordinate: [-5.981912536999971, 48.15441021400005]
# 	Distance to next coordinate: 39.78467037596738 km
# Processing coordinate 138: [-5.981912536999971, 48.15441021400005]
# 	Comparing with next coordinate: [-5.675363672999936, 48.45500940200003]
# 	Distance to next coordinate: 40.38953349324335 km
# Processing coordinate 139: [-5.675363672999936, 48.45500940200003]
# 	Comparing with next coordinate: [0.8511815590000538, 50.74869852300003]
# 	Distance to next coordinate: 534.76441125928 km
# Processing coordinate 140: [0.8511815590000538, 50.74869852300003]
# 	Comparing with next coordinate: [4.677502222000044, 53.70774545200004]
# 	Distance to next coordinate: 419.6078997122666 km
# Processing coordinate 141: [4.677502222000044, 53.70774545200004]
# 	Comparing with next coordinate: [7.174522994000029, 57.04005339400004]
# 	Distance to next coordinate: 402.6587397898057 km
# Processing coordinate 142: [7.174522994000029, 57.04005339400004]
# 	Comparing with next coordinate: [10.575215239000045, 58.276790324000046]
# 	Distance to next coordinate: 244.56356554984362 km
# Processing coordinate 143: [10.575215239000045, 58.276790324000046]
# 	Comparing with next coordinate: [11.449264265000068, 56.38182489600007]
# 	Distance to next coordinate: 217.13886375825032 km
# Processing coordinate 144: [11.449264265000068, 56.38182489600007]
# 	Comparing with next coordinate: [12.53692574300004, 54.98677156600007]
# 	Distance to next coordinate: 169.44032896033795 km
# Processing coordinate 145: [12.53692574300004, 54.98677156600007]
# 	Comparing with next coordinate: [15.651368257000058, 55.37689178900007]
# 	Distance to next coordinate: 202.4178058307372 km
# Processing coordinate 146: [15.651368257000058, 55.37689178900007]
# 	Comparing with next coordinate: [18.79559796700005, 56.75540469200007]
# 	Distance to next coordinate: 248.1274523537798 km
# Processing coordinate 147: [18.79559796700005, 56.75540469200007]
# 	Comparing with next coordinate: [21.55857336400004, 59.10152640700005]
# 	Distance to next coordinate: 307.6244845615232 km
# Processing coordinate 148: [21.55857336400004, 59.10152640700005]
# 	Comparing with next coordinate: [22.729170431000057, 59.594176221000055]
# 	Distance to next coordinate: 86.04813685605538 km
# Processing coordinate 149: [22.729170431000057, 59.594176221000055]
# 	Comparing with next coordinate: [27.455734990000053, 60.00246340400008]
# 	Distance to next coordinate: 268.194495320499 km
# /tmp/ipykernel_16736/160305113.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([
#                                         source  \
# 0      [-34.85759679699993, -8.13737959499997]
# 1     [-34.67436962399995, -8.070254808999948]
# 2    [-34.674368303999984, -8.070249185999955]
# 3    [-25.630149081999946, 16.957174956000074]
# 4    [-25.483361960999957, 17.286788839000053]
# ..                                         ...
# 145     [12.53692574300004, 54.98677156600007]
# 146    [15.651368257000058, 55.37689178900007]
# 147     [18.79559796700005, 56.75540469200007]
# 148     [21.55857336400004, 59.10152640700005]
# 149   [22.729170431000057, 59.594176221000055]
#
#                                         target       weight lane-type lane-idx
# 0     [-34.67436962399995, -8.070254808999948]    21.507177     Major        0
# 1    [-34.674368303999984, -8.070249185999955]     0.000642     Major        0
# 2    [-25.630149081999946, 16.957174956000074]  2955.268635     Major        0
# 3    [-25.483361960999957, 17.286788839000053]    39.832647     Major        0
# 4    [-25.337770409999962, 17.616515286000038]    39.783845     Major        0
# ..                                         ...          ...       ...      ...
# 145    [15.651368257000058, 55.37689178900007]   202.417806     Major        0
# 146     [18.79559796700005, 56.75540469200007]   248.127452     Major        0
# 147     [21.55857336400004, 59.10152640700005]   307.624485     Major        0
# 148   [22.729170431000057, 59.594176221000055]    86.048137     Major        0
# 149    [27.455734990000053, 60.00246340400008]   268.194495     Major        0
#
# [150 rows x 5 columns]
